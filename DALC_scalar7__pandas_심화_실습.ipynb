# %% [markdown]
# <a href="https://colab.research.google.com/github/YE-JIN-LEE/DALC_Scala/blob/main/DALC_scalar7__pandas_%EC%8B%AC%ED%99%94_%EC%8B%A4%EC%8A%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 주관식
# 셀을 더블클릭해서  : 다음에 답을 입력하세요.

# %% [markdown]
# * matplotlib 인터페이스에는 어떤 종류가 있나?
# plt.figure(), x=np.linspace, plt.subplot(2,1,1), plt.plot(x,np.sin(x)),
# plt.subplot(2,1,1), plt.plot(x,np.cos(x))

# %% [markdown]
# * matlab스타일의 장점은 무엇인가

# %% [markdown]
# * 객체지향스타일의 장점은 무엇인가
# 복잡하고 상세한 설정 가능, 파이썬 프로그램 친화적

# %% [markdown]
# * 객체지향스타일은 어떨 때 사용하는가
# 그림이 복잡하고 많은 설정이 필요할 때

# %% [markdown]
# # 빅데이터 시각화
# * matplotlib사용
# * 선그림과 점그림
# * 다중 서브플롯
#
# 해당 질문 밑에 있는 코드셀에 코드를 입력하세요

# %% [markdown]
# # matplotlib 인터페이스

# %% [markdown]
# ### matlab스타일 인터페이스

# %% [markdown]
# * matplotlib라이브러리 사용

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# * 그래프스타일 클래식으로 설정

# %%
plt.style.use('seaborn-whitegrid')

# %%
import numpy as np

# %% [markdown]
# * 두 개의 패널 중 첫 번째 패널을 생성하고 현재 축을 설정

# %%
plt.figure()
x=np.linspace(-10,10,100)

# %% [markdown]
# * 2행 1열 구조 그리드의 첫번째 패널에 사인 그래프 작성

# %%
plt.subplot(2,1,1)
plt.plot(x, np.sin(x))

# %% [markdown]
# * 2행 1열 구조 그리드의 두번째 패널에 코사인 그래프 작성

# %%
plt.subplot(2,1,2)
plt.plot(x,np.cos(x))

# %% [markdown]
# * 2행 1열의 축 객체의 배열을 형성하라

# %%
fig, ax = plt.subplots(2,1)

# %% [markdown]
# * 위의 형성한 객체에 1행에는 넘파이패키지의 sin()함수를 그려라

# %%
fig, ax = plt.subplots(2,1)
ax[0].plot(x,np.sin(x))

# %% [markdown]
# ### 기본선그림

# %% [markdown]
# ### 선그림(lineplot)
# * 위와 같은 것이 %로 시작하는 것을 jupyter notebook의 magic command라고 한다.
# * %who는 변수명의 리스트를 보여주고 %magic 은 모든 매직명령어를 보여준다.
# * 전체적인 magic 명령어에 대해서는 다음 블로그를 참고
# * http://studymake.tistory.com/601
# * matplotlib 을 jupyter notebook에서 사용할 때, plot의 이미지를 보여주기 위해 magic command를 사용하는데,
# * 이때 우리가 사용하는 inline 이외에도 다음과 같은 요소를 사용할 수 있다.
# * Available matplotlib backends: ['osx', 'qt4', 'qt5', 'gtk3', 'notebook', 'wx', 'qt', 'nbagg','gtk', 'tk', 'inline']

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import pandas as pd
import numpy as np

# %% [markdown]
# *  Series를 통한 line plot 그리기

# %%
s = pd.Series(np.random.randn(10).cumsum(), index=np.arange(0, 100, 10))
s
# Out:
# 0     0.711588
# 10    1.065216
# 20    1.279247
# 30    0.511954
# 40    0.597392
# 50   -0.405700
# 60   -2.434651
# 70   -0.341569
# 80    0.410162
# 90    0.205985
# dtype: float64

# %% [markdown]
# * 시리즈 s의 선그래프를 그려라

# %%
plt.plot(s)

# %% [markdown]
# *  DataFrame를 통한 line plot 그리기

# %%
df = pd.DataFrame(np.random.randn(10, 4).cumsum(axis=0),
                  columns=["A", "B", "C", "D"],
                  index=np.arange(0, 100, 10))
df
# Out:
#            A         B         C         D
# 0  -0.363598  0.160391  0.548581  0.437947
# 10  0.869213 -1.826127 -0.168814  0.242050
# 20 -1.073504 -0.152224 -0.072943  0.088459
# 30  0.439437  0.613068 -0.739068  1.343139
# 40  1.917535  0.606908  1.220611  0.769350
# 50  2.664503  0.539198  0.739727  1.094264
# 60  3.907416  0.460591 -0.955675  0.571965
# 70  2.850779  0.358559 -0.274302  1.128631
# 80  0.874308  2.070210  0.069615  2.334488
# 90  0.501386  3.442956  0.241940  3.018671

# %% [markdown]
# * 데이터프레임 df의 선그래프를 그려라

# %%
plt.plot(df)
# Out:
# [<matplotlib.lines.Line2D at 0x7ff484d5eb50>,
#  <matplotlib.lines.Line2D at 0x7ff484d3f8d0>,
#  <matplotlib.lines.Line2D at 0x7ff484d3f4d0>,
#  <matplotlib.lines.Line2D at 0x7ff484d3fa90>]

# %% [markdown]
# * 데이터프레임 df의 B열에 대해서만 선그래프를 그려라

# %%
plt.plot(df['B'])

# %%
s2 = pd.Series(np.random.rand(16), index=list("abcdefghijklmnop"))
s2
# Out:
# a    0.845788
# b    0.897565
# c    0.481212
# d    0.484460
# e    0.549383
# f    0.330575
# g    0.830791
# h    0.955248
# i    0.697945
# j    0.916823
# k    0.038791
# l    0.990953
# m    0.272777
# n    0.727428
# o    0.129927
# p    0.698615
# dtype: float64

# %% [markdown]
# ## 막대그래프그리기

# %% [markdown]
# * s2열에 대해서 막대그래프를 그려라

# %%
s2.plot.bar()

# %% [markdown]
# s2열에 대해서 가로방향의 막대그래프를 그려라

# %%
s2.plot.barh()

# %%
df2 = pd.DataFrame(np.random.rand(6, 4), 
                   index=["one", "two", "three", "four", "five", "six"],
                   columns=pd.Index(["A", "B", "C", "D"], name="Genus"))
df2
# Out:
# Genus         A         B         C         D
# one    0.453792  0.772802  0.010937  0.933687
# two    0.665372  0.050895  0.041621  0.502820
# three  0.916446  0.576823  0.752912  0.378561
# four   0.620982  0.655442  0.735699  0.702538
# five   0.608567  0.925812  0.382237  0.918307
# six    0.320141  0.244733  0.281917  0.798263

# %% [markdown]
# * 데이터프레임 df2의 누적막대그래프를 그려라

# %%
df2.plot.bar(stacked=True)

# %% [markdown]
# * 데이터프레임 df2의 가로방향의 누적막대그래프를 그려라

# %%
df2.plot.barh(stacked=True)

# %% [markdown]
# * s3의 히스토그램을 그려라
# (히스토그램은 인덱스가 필요없다.)

# %%
s2.plot.hist()

# %% [markdown]
# * x축의 구간개수를50개로 설정하여 s3를 히스토그램으로그려라

# %%
s2.plot.hist(bins=20)

# %% [markdown]
# ## 산점도 그리기

# %%
x1 = np.random.normal(1, 1, size=(100, 1))
x2 = np.random.normal(-2, 4, size=(100, 1))
X = np.concatenate((x1, x2), axis=1)
df3 = pd.DataFrame(X, columns=["x1", "x2"])
df3
# Out:
#           x1        x2
# 0   2.049406 -2.707897
# 1   1.642261  0.526865
# 2   2.180375 -1.688698
# 3   2.173568 -8.967012
# 4   1.651315  0.574480
# ..       ...       ...
# 95  1.721020 -6.392917
# 96  2.684360  3.866083
# 97 -0.592127 -0.533508
# 98  0.913845  2.233775
# 99  1.345659 -5.322349
#
# [100 rows x 2 columns]

# %% [markdown]
# * df3의 x1열을 x축으로 x2열을 y축으로 산점도를 그려라

# %%
df3.plot.scatter(x='x1', y='x2')

# %% [markdown]
# ##  플롯 조정
# * color
#
# 값 색상
#
# "b" blue
#
# "g" green
#
# "r" red
#
# "c" cyan
#
# "m" magenta
#
# "y" yellow
#
# "k" black
#
# "w" white
#
# * marker
#
# 값 마킹
#
# "." point
#
# "," pixel
#
# "o" circle
#
# "v" triangle_down
#
# "^" triangle_up
#
# "<" triangle_left
#
# ">" triangle_right
#
# "8" octagon
#
# "s" square
#
# "p" pentagon
#
# "*" star
#
# "h" hexagon
#
# "+" plus
#
# "x" x
#
# "D" diamond
#
# * line style
#
# 값 라인 스타일
#
# "-" solid line
#
# "--" dashed line
#
# "-." dash-dotted line
#
# ":" dotted line
#
# "None" draw nothing

# %% [markdown]
# * plt.plot(np.random.randn(50)에서 색상은 초록, 마킹모양은 원으로 선스타일은 dashed line으로 그려라

# %%
plt.plot(np.random.randn(50),'d--', color='g',  marker = 'o')

# %% [markdown]
# * y=x그래프를 solid green 옵션으로 그려라

# %%
y=x
plt.plot(x,x,color='g')

# %% [markdown]
# * y=x+1그래프를 dashed cyan 옵션으로 그려라

# %%
plt.plot(x, x+1, '--c')

# %% [markdown]
# * y=x+2 그래프를 dashdot black 옵션으로 그려라

# %%
plt.plot(x, x+2, '-.k')

# %% [markdown]
# * y=x+3그래프를 dotted red 옵션으로 그려라

# %%
plt.plot(x, x+3, ':r')

# %% [markdown]
# * 코사인 그래프를 그리고 x축의 범위를 (-1,11)로 y축의 범위를 (1.5,1.5)으로 설정해라

# %%
plt.plot(x, np.cos(x))
plt.xlim(-1,11)
plt.ylim(-1.5,1.5)
# Out:
# (-1.5, 1.5)

# %% [markdown]
# * 자연상수 그래프(np.exp(x)그래프를 그리고 y축의 스케일을 로그로 설정해라

# %%
plt.plot(x, np.exp(-x))
plt.yscale('log')

# %% [markdown]
# * 사인그래프를 그리고 축의 레이블를 a sine curve로 지정하고 x축의 레이블을 x, y축의 레이블을 sin(x)라 설정해라

# %%
plt.plot(x, np.cos(x))
plt.title('a sine curve')
plt.xlabel('x')
plt.ylabel('sin(x)')
# Out:
# Text(0, 0.5, 'sin(x)')

# %% [markdown]
# * 사인그래프를 그리고 옵션을 dash green , 레이블을 'sin(x)'로
# * 사인그래프를 그리고 옵션을 dott blue , 레이블을 'cos(x)'로
# * 두그래프의 x축의 범위를 동기화
# * 그래프의 제목을 'curves of sine and cosine'
# * x레이블을 'x'로
# * 범례표시해라

# %%
plt.plot(x, np.sin(x), '-g', label= 'sin(x)')
plt.plot(x, np.cos(x), ':b', label='cos(x)')
plt.axis('equal')
plt.title('curves of sine and cosine')
plt.xlabel('x')
plt.legend()
