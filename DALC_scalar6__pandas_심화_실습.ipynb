# %% [markdown]
# <a href="https://colab.research.google.com/github/YE-JIN-LEE/DALC_Scala/blob/main/DALC_scalar6__pandas_%EC%8B%AC%ED%99%94_%EC%8B%A4%EC%8A%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 주관식
# 셀을 더블클릭해서  : 다음에 답을 입력하세요.

# %% [markdown]
# * 데이터프레임 file의 클래스유형 :(csv)
# * 측정일시의 자료형 : object
# * 전체 데이터프레임의 자료형은 어떻게 구성되어있나(정수형?개,실수형?개,문자형?개): 문자형 14개
# * 메모리 사용량: 129.1+ KB

# %% [markdown]
# * value_counts()코드작성 결과 왼쪽숫자와 오른쪽숫자는 무엇을 의미하는가 :
# 왼쪽은 행, 인덱스, 오른쪽은 데이터 값

# %% [markdown]
# * min,max,std 같은 통계함수 반환결과는 어떤객체로 반환되는가?: 시리즈 객체

# %% [markdown]
# * 그래프를 만들기 위해 pandas내장 그래프인 plot()내장함수를 사용할때 , 히스토그램 그래프를 만들기 위한 kind값은: hist

# %% [markdown]
# * 데이터레코드는 무엇은 뜻하는가: 데이터 각 행의 자료
# * 중복된 데이터셋이 존재할 경우 분석결과에 어떤 영향이있나: 분석 결과를 왜곡한다

# %% [markdown]
# * 중복된 데이터셋이 있을경우 true로 반환되는가 false로 반환되는가? True

# %% [markdown]
# # Pandas 심화실습
# * 파일읽기와 쓰기
# * 데이터프레임 구조
# * 통계 함수
#
# 해당 질문 밑에 있는 코드셀에 코드를 입력하세요

# %% [markdown]
# # csv파일

# %% [markdown]
# * 판다스,넘파이 임포트하기

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# * (성북구)서울생활인구 일별 집계표를 read_csv()함수로 file변수에 저장해라

# %%
file=pd.read_csv('/content/drive/MyDrive/(성북구) 서울생활인구 일별 집계표.csv',header=None,encoding='euc-kr')
file
# Out:
#             0      1     2   ...           12              13            14
# 0        기준일ID  시군구코드  시군구명  ...     서울외유입인구수  동일자치구행정동간이동인구수     자치구간이동인구수
# 1     20210425  11290   성북구  ...  20646.80240     91937.32060   55776.95080
# 2     20210424  11290   성북구  ...  22332.52960     88407.36780   62452.17210
# 3     20210423  11290   성북구  ...  22768.37600     93289.93880   76926.18900
# 4     20210422  11290   성북구  ...  23795.99210     94515.73460   79166.29070
# ...        ...    ...   ...  ...          ...             ...           ...
# 1098  20180409  11290   성북구  ...  30769.73320    103022.83580  106705.06490
# 1099  20180408  11290   성북구  ...  24703.28610     98189.04260   70396.93210
# 1100  20180407  11290   성북구  ...  26331.93420     95319.36890   74564.74500
# 1101  20180406  11290   성북구  ...  27578.37090     99137.54820   99422.38170
# 1102  20180405  11290   성북구  ...  29719.85340    101150.79300  104208.28520
#
# [1103 rows x 15 columns]

# %%
file=file.drop([2],axis=1)
file=file.drop([0],axis=0)
file.columns=['기준일ID', '시군구코드', '총생활인구수', '내국인생활인구수', '장기체류외국인인구수', '단기체류외국인인구수', '일최대인구수', '일최소인구수', '주간인구수', '야간인구수', '일최대이동인구수', '서울외유입인구수', '동일자치구행정동간이동인구수', '자치구간이동인구수']

# %% [markdown]
# * 데이터프레임 file의 앞에 5줄 데이터 조회

# %%
file.head(5)
# Out:
#       기준일ID  시군구코드        총생활인구수  ...     서울외유입인구수 동일자치구행정동간이동인구수    자치구간이동인구수
# 1  20210425  11290  443639.45680  ...  20646.80240    91937.32060  55776.95080
# 2  20210424  11290  437840.32410  ...  22332.52960    88407.36780  62452.17210
# 3  20210423  11290  435185.36780  ...  22768.37600    93289.93880  76926.18900
# 4  20210422  11290  438600.35210  ...  23795.99210    94515.73460  79166.29070
# 5  20210421  11290  439620.82590  ...  24139.00400    95286.48550  80989.71480
#
# [5 rows x 14 columns]

# %% [markdown]
# * 데이터프레임 file의 뒤에 5줄 데이터 조회

# %%
file.tail(5)
# Out:
#          기준일ID  시군구코드        총생활인구수  ...     서울외유입인구수 동일자치구행정동간이동인구수     자치구간이동인구수
# 1098  20180409  11290  476114.24590  ...  30769.73320   103022.83580  106705.06490
# 1099  20180408  11290  477840.49290  ...  24703.28610    98189.04260   70396.93210
# 1100  20180407  11290  466144.52940  ...  26331.93420    95319.36890   74564.74500
# 1101  20180406  11290  469243.02000  ...  27578.37090    99137.54820   99422.38170
# 1102  20180405  11290  477444.98960  ...  29719.85340   101150.79300  104208.28520
#
# [5 rows x 14 columns]

# %% [markdown]
# * 데이터프레임 file의 앞에 10줄 데이터 조회

# %%
file.head(10)
# Out:
#        기준일ID  시군구코드        총생활인구수  ...     서울외유입인구수 동일자치구행정동간이동인구수    자치구간이동인구수
# 1   20210425  11290  443639.45680  ...  20646.80240    91937.32060  55776.95080
# 2   20210424  11290  437840.32410  ...  22332.52960    88407.36780  62452.17210
# 3   20210423  11290  435185.36780  ...  22768.37600    93289.93880  76926.18900
# 4   20210422  11290  438600.35210  ...  23795.99210    94515.73460  79166.29070
# 5   20210421  11290  439620.82590  ...  24139.00400    95286.48550  80989.71480
# 6   20210420  11290  439129.50660  ...  23696.82220    95415.24410  80379.40850
# 7   20210419  11290  439863.02470  ...  22334.97850    96001.37290  77991.72340
# 8   20210418  11290  446964.27350  ...  19958.70620    92165.15530  57251.63430
# 9   20210417  11290  443367.24500  ...  21767.26460    89067.68400  61809.37910
# 10  20210416  11290  438868.27820  ...  21812.91260    93713.39440  76463.14590
#
# [10 rows x 14 columns]

# %% [markdown]
# #  데이터 요약정보 확인하기

# %% [markdown]
# * 데이터프레임 모양과 크기 확인

# %%
file.shape
# Out:
# (1102, 14)

# %% [markdown]
# * 데이터프레임 기본정보 조회

# %%
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1102 entries, 1 to 1102
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   기준일ID           1102 non-null   object
#  1   시군구코드           1102 non-null   object
#  2   총생활인구수          1102 non-null   object
#  3   내국인생활인구수        1102 non-null   object
#  4   장기체류외국인인구수      1102 non-null   object
#  5   단기체류외국인인구수      1102 non-null   object
#  6   일최대인구수          1102 non-null   object
#  7   일최소인구수          1102 non-null   object
#  8   주간인구수           1102 non-null   object
#  9   야간인구수           1102 non-null   object
#  10  일최대이동인구수        1102 non-null   object
#  11  서울외유입인구수        1102 non-null   object
#  12  동일자치구행정동간이동인구수  1102 non-null   object
#  13  자치구간이동인구수       1102 non-null   object
# dtypes: object(14)
# memory usage: 129.1+ KB

# %% [markdown]
# * 데이터프레임의 각열의 자료형 확인

# %%
file.dtypes
# Out:
# 기준일ID             object
# 시군구코드             object
# 총생활인구수            object
# 내국인생활인구수          object
# 장기체류외국인인구수        object
# 단기체류외국인인구수        object
# 일최대인구수            object
# 일최소인구수            object
# 주간인구수             object
# 야간인구수             object
# 일최대이동인구수          object
# 서울외유입인구수          object
# 동일자치구행정동간이동인구수    object
# 자치구간이동인구수         object
# dtype: object

# %% [markdown]
# * '일최대이동인구수' 열에 대해 dtypes속성 적용

# %%
file.일최대이동인구수.dtypes
# Out:
# dtype('O')

# %% [markdown]
# * 데이터프레임의 기술통계정보를 보여라

# %%
file.describe()
# Out:
#            기준일ID  시군구코드        총생활인구수  ...     서울외유입인구수 동일자치구행정동간이동인구수    자치구간이동인구수
# count       1102   1102          1102  ...         1102           1102         1102
# unique      1102      1          1102  ...         1102           1102         1102
# top     20201125  11290  466940.45510  ...  22552.89920    81037.50140  72824.64610
# freq           1   1102             1  ...            1              1            1
#
# [4 rows x 14 columns]

# %% [markdown]
# * 각 열의 데이터 개수 확인하는 코드 작성

# %%
file.count()
# Out:
# 기준일ID             1102
# 시군구코드             1102
# 총생활인구수            1102
# 내국인생활인구수          1102
# 장기체류외국인인구수        1102
# 단기체류외국인인구수        1102
# 일최대인구수            1102
# 일최소인구수            1102
# 주간인구수             1102
# 야간인구수             1102
# 일최대이동인구수          1102
# 서울외유입인구수          1102
# 동일자치구행정동간이동인구수    1102
# 자치구간이동인구수         1102
# dtype: int64

# %% [markdown]
# * '일최대이동인구수'열의 고유값 개수 확인하는 코드 작성

# %%
file['일최대이동인구수'].value_counts()
# Out:
# 188339.98430    1
# 208808.56010    1
# 164489.52040    1
# 207558.12260    1
# 167450.76990    1
#                ..
# 186489.67160    1
# 197042.36600    1
# 179360.59180    1
# 192050.68900    1
# 228577.40590    1
# Name: 일최대이동인구수, Length: 1102, dtype: int64

# %% [markdown]
# # 통계함수

# %% [markdown]
# * file데이터프레임의 평균값 계산해라

# %%
file = file.apply(pd.to_numeric)
file.mean()
# Out:
# 기준일ID             2.019361e+07
# 시군구코드             1.129000e+04
# 총생활인구수            4.494037e+05
# 내국인생활인구수          4.311108e+05
# 장기체류외국인인구수        1.555597e+04
# 단기체류외국인인구수        2.736974e+03
# 일최대인구수            4.768937e+05
# 일최소인구수            4.194113e+05
# 주간인구수             4.268647e+05
# 야간인구수             4.654147e+05
# 일최대이동인구수          1.897678e+05
# 서울외유입인구수          2.512069e+04
# 동일자치구행정동간이동인구수    9.017110e+04
# 자치구간이동인구수         7.447600e+04
# dtype: float64

# %% [markdown]
# * '일최대이동인구수'열의 평균을 계산해라

# %%
file['일최대이동인구수'].mean()
# Out:
# 189767.78237604344

# %% [markdown]
# * file데이터프레임의 중간값을 확인해라

# %%
file.median()
# Out:
# 기준일ID             2.019101e+07
# 시군구코드             1.129000e+04
# 총생활인구수            4.486198e+05
# 내국인생활인구수          4.304522e+05
# 장기체류외국인인구수        1.567238e+04
# 단기체류외국인인구수        2.440120e+03
# 일최대인구수            4.761578e+05
# 일최소인구수            4.177012e+05
# 주간인구수             4.253037e+05
# 야간인구수             4.650200e+05
# 일최대이동인구수          1.884541e+05
# 서울외유입인구수          2.438078e+04
# 동일자치구행정동간이동인구수    9.060589e+04
# 자치구간이동인구수         7.385048e+04
# dtype: float64

# %% [markdown]
# * '일최대이동인구수'열의 중간값을 확인해라

# %%
file['일최대이동인구수'].median()
# Out:
# 188454.05404999998

# %% [markdown]
# * file데이터프레임의 최대값을 계산해라

# %%
file.max()
# Out:
# 기준일ID             2.021042e+07
# 시군구코드             1.129000e+04
# 총생활인구수            5.004634e+05
# 내국인생활인구수          4.809744e+05
# 장기체류외국인인구수        1.919045e+04
# 단기체류외국인인구수        7.503387e+03
# 일최대인구수            6.264549e+05
# 일최소인구수            4.659571e+05
# 주간인구수             4.758505e+05
# 야간인구수             5.377383e+05
# 일최대이동인구수          2.432134e+05
# 서울외유입인구수          5.540911e+04
# 동일자치구행정동간이동인구수    1.030228e+05
# 자치구간이동인구수         1.088423e+05
# dtype: float64

# %% [markdown]
# * '일최대이동인구수'열의 최대값을 계산해라

# %%
file['일최대이동인구수'].max()
# Out:
# 243213.4016

# %% [markdown]
# * file데이터프레임의 최솟값을 계산해라

# %%
file.min()
# Out:
# 기준일ID             2.018040e+07
# 시군구코드             1.129000e+04
# 총생활인구수            4.058767e+05
# 내국인생활인구수          3.897026e+05
# 장기체류외국인인구수        1.081888e+04
# 단기체류외국인인구수        1.049794e+03
# 일최대인구수            4.234127e+05
# 일최소인구수            3.680632e+05
# 주간인구수             3.755489e+05
# 야간인구수             4.162432e+05
# 일최대이동인구수          8.634689e+04
# 서울외유입인구수          1.515896e+04
# 동일자치구행정동간이동인구수    3.626779e+04
# 자치구간이동인구수         2.265375e+04
# dtype: float64

# %% [markdown]
# * '일최대이동인구수'열의 최솟값을 계산해라

# %%
file['일최대이동인구수'].min()
# Out:
# 86346.8876

# %% [markdown]
# * file데이터프레임의 표준편차를 계산해라

# %%
file.std()
# Out:
# 기준일ID              9414.096299
# 시군구코드                 0.000000
# 총생활인구수            14008.605145
# 내국인생활인구수          12998.571695
# 장기체류외국인인구수         1683.981870
# 단기체류외국인인구수          944.610050
# 일최대인구수            15000.608760
# 일최소인구수            16642.345130
# 주간인구수             16402.525671
# 야간인구수             13685.651941
# 일최대이동인구수          19712.498982
# 서울외유입인구수           4502.801248
# 동일자치구행정동간이동인구수     5554.796026
# 자치구간이동인구수         13214.268720
# dtype: float64

# %% [markdown]
# * '일최대이동인구수'열의 표준편차를 계산해라

# %%
file['일최대이동인구수'].std()
# Out:
# 19712.49898194962

# %% [markdown]
# * '자치구간이동인구수''와 '일최대이동인구수'의 상관계수를 계산해라

# %%
file[['자치구간이동인구수', '일최대이동인구수']].corr()
# Out:
#            자치구간이동인구수  일최대이동인구수
# 자치구간이동인구수   1.000000  0.973829
# 일최대이동인구수    0.973829  1.000000

# %% [markdown]
# # Pandas 심화(2)
# * 판다스 내장 그래픽 활용
# * 중복 데이터 처리

# %% [markdown]
# * matplotlib라이브러리호출 (mpl로 약칭)

# %%
import matplotlib as mpl

# %% [markdown]
# * matplotlib라이브러리의 pyplot함수 호출 (plt로 약칭)

# %%
import matplotlib.pyplot as plt

# %%
data=file.iloc[:,4:]

# %% [markdown]
# * data의 선그래프 그리기

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# fonts-nanum is already the newest version (20170925-1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 34 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 10 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %%
import matplotlib.pyplot as plt

plt.rc('font', family='NanumBarunGothic')

# %%
file.plot()

# %% [markdown]
# * data의 히스토그램 그리기

# %%
file.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f316a95e150>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f316a928e90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f316a8ae8d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f316a8e3f50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f316a8a3610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f316a859c90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f316a81c3d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f316a7d1990>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f316a7d19d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f316a793190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f316a6fed90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f316a6c1450>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f316a675ad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f316a637190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f316a5f6a10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f316a620b90>]],
#       dtype=object)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# * data의 자치구간이동인구수와 일최대이동인구수 산점도 그리기

# %%
file.plot(x='자치구간이동인구수', y='일최대이동인구수', kind='scatter')

# %% [markdown]
# * data의 자치구간이동인구수와 일최대이동인구수 박스플롯 그리기

# %%
file[['자치구간이동인구수', '일최대이동인구수']].plot(kind='box')

# %% [markdown]
# * 위의 코드 결과 미세먼지와 초미세먼지중 평균이 높은것은?:(답은 여기에 작성)

# %% [markdown]
# # 중복 데이터 처리

# %% [markdown]
# * 다음 사진과 같이 데이터프레임을 생성해라
#
# ![캡처.PNG](data:image/png;base64,...)

# %%
dataSet = pd.DataFrame({'A' : ['a', 'a', 'b','a','b'],
                        'B' : [1,1,1,2,1],
                        'C' : [1,1,2,2,2]})
dataSet
# Out:
#    A  B  C
# 0  a  1  1
# 1  a  1  1
# 2  b  1  2
# 3  a  2  2
# 4  b  1  2

# %% [markdown]
# * 중복 데이터 확인해라(이전행과 현재행 비교)

# %%
dataSet.duplicated()
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4     True
# dtype: bool

# %% [markdown]
# * 중복 데이터를 삭제하고 고유한 값만을 가지 행들만 남겨라(원본에 저장)

# %%
dataSet = dataSet.drop_duplicates()
dataSet
# Out:
#    A  B  C
# 0  a  1  1
# 2  b  1  2
# 3  a  2  2

# %% [markdown]
# * B열과 C열기준으로 중복 여부를 판단해라

# %%
dataSet_sub = dataSet.drop_duplicates(subset=['B', 'C'])
dataSet_sub
# Out:
#    A  B  C
# 0  a  1  1
# 2  b  1  2
# 3  a  2  2
